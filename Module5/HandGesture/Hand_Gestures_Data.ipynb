# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: opencv-python in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 2)) (4.10.0.84)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 3)) (11.0.0)
# Requirement already satisfied: pascal_voc_writer in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: cvzone in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: pyyaml in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: mediapipe==0.10.18 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 8)) (0.10.18)
# Requirement already satisfied: torch==2.5.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: pyserial in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from -r requirements.txt (line 10)) (3.5)
# Requirement already satisfied: absl-py in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (24.3.25)
# Requirement already satisfied: jax in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (0.4.35)
# Requirement already satisfied: jaxlib in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (0.4.35)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (3.9.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (4.25.5)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: sentencepiece in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from mediapipe==0.10.18->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from torch==2.5.0->-r requirements.txt (line 9)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from torch==2.5.0->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from torch==2.5.0->-r requirements.txt (line 9)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from torch==2.5.0->-r requirements.txt (line 9)) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from torch==2.5.0->-r requirements.txt (line 9)) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from torch==2.5.0->-r requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from sympy==1.13.1->torch==2.5.0->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from pandas->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from pandas->-r requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from pandas->-r requirements.txt (line 7)) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from sounddevice>=0.4.4->mediapipe==0.10.18->-r requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.4.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from jax->mediapipe==0.10.18->-r requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: opt-einsum in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from jax->mediapipe==0.10.18->-r requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from jax->mediapipe==0.10.18->-r requirements.txt (line 8)) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from jinja2->torch==2.5.0->-r requirements.txt (line 9)) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from matplotlib->mediapipe==0.10.18->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from matplotlib->mediapipe==0.10.18->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from matplotlib->mediapipe==0.10.18->-r requirements.txt (line 8)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from matplotlib->mediapipe==0.10.18->-r requirements.txt (line 8)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from matplotlib->mediapipe==0.10.18->-r requirements.txt (line 8)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from matplotlib->mediapipe==0.10.18->-r requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\envs\gesture_env\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18->-r requirements.txt (line 8)) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import csv
import yaml
import numpy as np
import mediapipe as mp


def is_handsign_character(char: str):
    return ord('a') <= ord(char) < ord("q") or char == " "


def label_dict_from_config_file(relative_path):
    with open(relative_path, "r") as f:
        label_tag = yaml.full_load(f)["gestures"]
    return label_tag


class HandDatasetWriter():
    def __init__(self, filepath) -> None:
        self.csv_file = open(filepath, "a")
        self.file_writer = csv.writer(
            self.csv_file, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    def add(self, hand, label):
        self.file_writer.writerow([label, *np.array(hand).flatten().tolist()])

    def close(self):
        self.csv_file.close()


class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(
            False, max_num_hands=1, min_detection_confidence=0.5)

    def detectHand(self, frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x, y, z = landmark.x, landmark.y, landmark.z
                    hand.extend([x, y, z])
            hands.append(hand)
        return hands, annotated_image


def run(data_path, sign_img_path, split="val", resolution=(1280, 720)):

    hand_detector = HandLandmarksDetector()
    cam = cv2.VideoCapture(0)
    cam.set(3, resolution[0])
    cam.set(4, resolution[1])

    os.makedirs(data_path, exist_ok=True)
    os.makedirs(sign_img_path, exist_ok=True)
    print(sign_img_path)
    dataset_path = f"./{data_path}/landmark_{split}.csv"
    hand_dataset = HandDatasetWriter(dataset_path)
    current_letter = None
    status_text = None
    cannot_switch_char = False

    saved_frame = None
    while cam.isOpened():
        _, frame = cam.read()
        hands, annotated_image = hand_detector.detectHand(frame)

        if (current_letter is None):
            status_text = "press a character to record"

        else:
            label = ord(current_letter)-ord("a")
            if label == -65:
                status_text = f"Recording unknown, press spacebar again to stop"
                label = -1
            else:
                status_text = f"Recording {LABEL_TAG[label]}, press {current_letter} again to stop"

        key = cv2.waitKey(1)
        if (key == -1):
            if (current_letter is None):
                # no current letter recording, just skip it
                pass
            else:
                if len(hands) != 0:
                    hand = hands[0]
                    hand_dataset.add(hand=hand, label=label)
                    saved_frame = frame
        # some key is pressed
        else:
            # pressed some key, do not push this image, assign current letter to the key just pressed
            key = chr(key)
            if key == "q":
                break
            if (is_handsign_character(key)):
                if (current_letter is None):
                    current_letter = key
                elif (current_letter == key):
                    # pressed again?, reset the current state
                    if saved_frame is not None:
                        if label >= 0:
                            cv2.imwrite(
                                f"./{sign_img_path}/{LABEL_TAG[label]}.jpg", saved_frame)

                    cannot_switch_char = False
                    current_letter = None
                    saved_frame = None
                else:
                    cannot_switch_char = True
                    # warned user to unbind the current_letter first
        if (cannot_switch_char):
            cv2.putText(annotated_image, f"please press {current_letter} again to unbind", (
                0, 450), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

        cv2.putText(annotated_image, status_text, (5, 20),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
        cv2.imshow(f"{split}", annotated_image)
    cv2.destroyAllWindows()


if __name__ == "__main__":
    LABEL_TAG = label_dict_from_config_file('hand_gesture.yaml')
    data_path = './data2'
    sign_img_path = './sign_imgs2'
    run(data_path, sign_img_path, "train", (1280, 720))
    run(data_path, sign_img_path, "val", (1280, 720))
    run(data_path, sign_img_path, "test", (1280, 720))
# Out:
# ./sign_imgs2
# ./sign_imgs2
# ./sign_imgs2
